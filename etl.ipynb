# %%
# %pip install glob2 psycopg2 pandas sql_queries

# %%
import os
import glob2
import psycopg2
import pandas as pd
from sql_queries import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       3 import psycopg2
#       4 import pandas as pd
# ----> 5 from sql_queries import *
#
# ModuleNotFoundError: No module named 'sql_queries'

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=europeanalysis user=host password=host")
cur = conn.cursor()
